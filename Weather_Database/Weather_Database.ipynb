# %%
# Import dependencies. 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
import os

cwd = os.getcwd()  # Get the current working directory (cwd)
files = os.listdir(cwd)  # Get all the files in that directory
print("Files in %r: %s" % (cwd, files))
# Out:
# Files in '/Users/jessicajohnson/Desktop/Bootcamp/World_Weather_Analysis/Weather_Database': ['Weather_Database.ipynb', '.DS_Store', 'config.py', 'WeatherPy_Database.csv', '__pycache__', '.ipynb_checkpoints']

# %%
# Create a set of random latitude and lognitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and lognitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the list of cities.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 770

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3e5efb6fe89b37682abebc20c98bd6c3

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        
    
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Current Description" : city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
        
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | lodja
# Processing Record 2 of Set 1 | bethel
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | ushuaia
# Processing Record 5 of Set 1 | khatanga
# Processing Record 6 of Set 1 | evensk
# Processing Record 7 of Set 1 | tadine
# Processing Record 8 of Set 1 | ribeira grande
# Processing Record 9 of Set 1 | vaini
# Processing Record 10 of Set 1 | cape town
# Processing Record 11 of Set 1 | rikitea
# Processing Record 12 of Set 1 | bar harbor
# Processing Record 13 of Set 1 | mys shmidta
# City not found. Skipping...
# Processing Record 14 of Set 1 | mataura
# Processing Record 15 of Set 1 | punta arenas
# Processing Record 16 of Set 1 | lake charles
# Processing Record 17 of Set 1 | east london
# Processing Record 18 of Set 1 | saint anthony
# Processing Record 19 of Set 1 | cabo san lucas
# Processing Record 20 of Set 1 | puerto ayora
# Processing Record 21 of Set 1 | yellowknife
# Processing Record 22 of Set 1 | kudahuvadhoo
# Processing Record 23 of Set 1 | katangli
# Processing Record 24 of Set 1 | busselton
# Processing Record 25 of Set 1 | bolungarvik
# City not found. Skipping...
# Processing Record 26 of Set 1 | srivardhan
# Processing Record 27 of Set 1 | dikson
# Processing Record 28 of Set 1 | hithadhoo
# Processing Record 29 of Set 1 | tahoua
# Processing Record 30 of Set 1 | abu dhabi
# Processing Record 31 of Set 1 | paamiut
# Processing Record 32 of Set 1 | sabha
# Processing Record 33 of Set 1 | vaitupu
# City not found. Skipping...
# Processing Record 34 of Set 1 | betare oya
# Processing Record 35 of Set 1 | el paso
# Processing Record 36 of Set 1 | san cristobal
# Processing Record 37 of Set 1 | lebu
# Processing Record 38 of Set 1 | veraval
# Processing Record 39 of Set 1 | carnarvon
# Processing Record 40 of Set 1 | jining
# Processing Record 41 of Set 1 | sabinas
# Processing Record 42 of Set 1 | namatanai
# Processing Record 43 of Set 1 | sovetskiy
# Processing Record 44 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 45 of Set 1 | kahului
# Processing Record 46 of Set 1 | arraial do cabo
# Processing Record 47 of Set 1 | birao
# Processing Record 48 of Set 1 | ariquemes
# Processing Record 49 of Set 1 | hami
# Processing Record 50 of Set 1 | moroni
# Processing Record 1 of Set 2 | mamallapuram
# Processing Record 2 of Set 2 | ugoofaaru
# Processing Record 3 of Set 2 | synya
# Processing Record 4 of Set 2 | lolua
# City not found. Skipping...
# Processing Record 5 of Set 2 | barentsburg
# City not found. Skipping...
# Processing Record 6 of Set 2 | lompoc
# Processing Record 7 of Set 2 | bredasdorp
# Processing Record 8 of Set 2 | leningradskiy
# Processing Record 9 of Set 2 | el wasta
# City not found. Skipping...
# Processing Record 10 of Set 2 | broome
# Processing Record 11 of Set 2 | saint-philippe
# Processing Record 12 of Set 2 | coquimbo
# Processing Record 13 of Set 2 | bambous virieux
# Processing Record 14 of Set 2 | chuy
# Processing Record 15 of Set 2 | peddapalli
# Processing Record 16 of Set 2 | atuona
# Processing Record 17 of Set 2 | dromolaxia
# Processing Record 18 of Set 2 | butaritari
# Processing Record 19 of Set 2 | jamestown
# Processing Record 20 of Set 2 | hovd
# Processing Record 21 of Set 2 | majene
# Processing Record 22 of Set 2 | georgetown
# Processing Record 23 of Set 2 | waipawa
# Processing Record 24 of Set 2 | cidreira
# Processing Record 25 of Set 2 | biak
# Processing Record 26 of Set 2 | port elizabeth
# Processing Record 27 of Set 2 | mahebourg
# Processing Record 28 of Set 2 | talnakh
# Processing Record 29 of Set 2 | hobart
# Processing Record 30 of Set 2 | chokurdakh
# Processing Record 31 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 32 of Set 2 | nacala
# Processing Record 33 of Set 2 | albany
# Processing Record 34 of Set 2 | geraldton
# Processing Record 35 of Set 2 | banda aceh
# Processing Record 36 of Set 2 | effium
# Processing Record 37 of Set 2 | hermanus
# Processing Record 38 of Set 2 | half moon bay
# Processing Record 39 of Set 2 | espanola
# Processing Record 40 of Set 2 | sumbe
# Processing Record 41 of Set 2 | tomigusuku
# Processing Record 42 of Set 2 | esperance
# Processing Record 43 of Set 2 | belaya gora
# Processing Record 44 of Set 2 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 2 | undory
# Processing Record 46 of Set 2 | roald
# Processing Record 47 of Set 2 | ransang
# Processing Record 48 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 49 of Set 2 | qaanaaq
# Processing Record 50 of Set 2 | sao gabriel da cachoeira
# Processing Record 1 of Set 3 | barrow
# Processing Record 2 of Set 3 | hilo
# Processing Record 3 of Set 3 | tiznit
# Processing Record 4 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 5 of Set 3 | labutta
# City not found. Skipping...
# Processing Record 6 of Set 3 | torbay
# Processing Record 7 of Set 3 | yarada
# Processing Record 8 of Set 3 | bonthe
# Processing Record 9 of Set 3 | oistins
# Processing Record 10 of Set 3 | berlevag
# Processing Record 11 of Set 3 | samusu
# City not found. Skipping...
# Processing Record 12 of Set 3 | tasiilaq
# Processing Record 13 of Set 3 | kodiak
# Processing Record 14 of Set 3 | tiksi
# Processing Record 15 of Set 3 | victoria
# Processing Record 16 of Set 3 | mana
# Processing Record 17 of Set 3 | da nang
# Processing Record 18 of Set 3 | san quintin
# Processing Record 19 of Set 3 | longyearbyen
# Processing Record 20 of Set 3 | byron bay
# Processing Record 21 of Set 3 | laguna
# Processing Record 22 of Set 3 | isiro
# Processing Record 23 of Set 3 | touros
# Processing Record 24 of Set 3 | warrington
# Processing Record 25 of Set 3 | upernavik
# Processing Record 26 of Set 3 | bluff
# Processing Record 27 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 3 | chinsali
# Processing Record 29 of Set 3 | borba
# Processing Record 30 of Set 3 | sungairaya
# Processing Record 31 of Set 3 | new norfolk
# Processing Record 32 of Set 3 | luderitz
# Processing Record 33 of Set 3 | kununurra
# Processing Record 34 of Set 3 | tuktoyaktuk
# Processing Record 35 of Set 3 | kargopol
# Processing Record 36 of Set 3 | znamenskoye
# Processing Record 37 of Set 3 | tucumcari
# Processing Record 38 of Set 3 | ostrovnoy
# Processing Record 39 of Set 3 | tura
# Processing Record 40 of Set 3 | vao
# Processing Record 41 of Set 3 | lang son
# Processing Record 42 of Set 3 | miltenberg
# Processing Record 43 of Set 3 | college
# Processing Record 44 of Set 3 | prince rupert
# Processing Record 45 of Set 3 | severo-kurilsk
# Processing Record 46 of Set 3 | ilulissat
# Processing Record 47 of Set 3 | adrar
# Processing Record 48 of Set 3 | pokhara
# Processing Record 49 of Set 3 | tumannyy
# City not found. Skipping...
# Processing Record 50 of Set 3 | agua verde
# Processing Record 1 of Set 4 | hunza
# City not found. Skipping...
# Processing Record 2 of Set 4 | tricase
# Processing Record 3 of Set 4 | shediac
# Processing Record 4 of Set 4 | port alfred
# Processing Record 5 of Set 4 | ust-omchug
# Processing Record 6 of Set 4 | qaqortoq
# Processing Record 7 of Set 4 | bargal
# City not found. Skipping...
# Processing Record 8 of Set 4 | vila velha
# Processing Record 9 of Set 4 | santa rosa
# Processing Record 10 of Set 4 | yaan
# Processing Record 11 of Set 4 | jati
# Processing Record 12 of Set 4 | husavik
# Processing Record 13 of Set 4 | selyatino
# Processing Record 14 of Set 4 | provideniya
# Processing Record 15 of Set 4 | tsihombe
# City not found. Skipping...
# Processing Record 16 of Set 4 | cervia
# Processing Record 17 of Set 4 | carutapera
# Processing Record 18 of Set 4 | saint george
# Processing Record 19 of Set 4 | guerrero negro
# Processing Record 20 of Set 4 | komsomolskiy
# Processing Record 21 of Set 4 | mouzakion
# City not found. Skipping...
# Processing Record 22 of Set 4 | balkhash
# Processing Record 23 of Set 4 | misratah
# Processing Record 24 of Set 4 | srednekolymsk
# Processing Record 25 of Set 4 | noumea
# Processing Record 26 of Set 4 | orlik
# Processing Record 27 of Set 4 | klaksvik
# Processing Record 28 of Set 4 | nikolskoye
# Processing Record 29 of Set 4 | saint-joseph
# Processing Record 30 of Set 4 | bengkulu
# Processing Record 31 of Set 4 | hambantota
# Processing Record 32 of Set 4 | huarmey
# Processing Record 33 of Set 4 | bokajan
# Processing Record 34 of Set 4 | deming
# Processing Record 35 of Set 4 | sola
# Processing Record 36 of Set 4 | berezniki
# Processing Record 37 of Set 4 | wagar
# Processing Record 38 of Set 4 | fortuna
# Processing Record 39 of Set 4 | mhlume
# Processing Record 40 of Set 4 | magrath
# Processing Record 41 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 42 of Set 4 | souillac
# Processing Record 43 of Set 4 | mount gambier
# Processing Record 44 of Set 4 | avarua
# Processing Record 45 of Set 4 | alofi
# Processing Record 46 of Set 4 | shamkhal
# Processing Record 47 of Set 4 | parrita
# Processing Record 48 of Set 4 | san patricio
# Processing Record 49 of Set 4 | cintalapa
# Processing Record 50 of Set 4 | bundaberg
# Processing Record 1 of Set 5 | mar del plata
# Processing Record 2 of Set 5 | alta floresta
# Processing Record 3 of Set 5 | qui nhon
# Processing Record 4 of Set 5 | bulgan
# Processing Record 5 of Set 5 | dingle
# Processing Record 6 of Set 5 | comodoro rivadavia
# Processing Record 7 of Set 5 | egvekinot
# Processing Record 8 of Set 5 | cabedelo
# Processing Record 9 of Set 5 | thompson
# Processing Record 10 of Set 5 | codrington
# Processing Record 11 of Set 5 | saskylakh
# Processing Record 12 of Set 5 | ohara
# Processing Record 13 of Set 5 | douglas
# Processing Record 14 of Set 5 | zhanatas
# City not found. Skipping...
# Processing Record 15 of Set 5 | loandjili
# Processing Record 16 of Set 5 | vredendal
# Processing Record 17 of Set 5 | daru
# Processing Record 18 of Set 5 | hasaki
# Processing Record 19 of Set 5 | coahuayana
# Processing Record 20 of Set 5 | svetlogorsk
# Processing Record 21 of Set 5 | yar-sale
# Processing Record 22 of Set 5 | armacao dos buzios
# City not found. Skipping...
# Processing Record 23 of Set 5 | vostok
# Processing Record 24 of Set 5 | rio grande
# Processing Record 25 of Set 5 | mahajanga
# Processing Record 26 of Set 5 | pimentel
# Processing Record 27 of Set 5 | antofagasta
# Processing Record 28 of Set 5 | nguiu
# City not found. Skipping...
# Processing Record 29 of Set 5 | santa ana
# Processing Record 30 of Set 5 | lorengau
# Processing Record 31 of Set 5 | clyde river
# Processing Record 32 of Set 5 | nemuro
# Processing Record 33 of Set 5 | castro
# Processing Record 34 of Set 5 | mutsamudu
# City not found. Skipping...
# Processing Record 35 of Set 5 | constitucion
# Processing Record 36 of Set 5 | andenes
# Processing Record 37 of Set 5 | maldonado
# Processing Record 38 of Set 5 | portland
# Processing Record 39 of Set 5 | matay
# Processing Record 40 of Set 5 | alamosa
# Processing Record 41 of Set 5 | camana
# Processing Record 42 of Set 5 | bubaque
# Processing Record 43 of Set 5 | mitsamiouli
# Processing Record 44 of Set 5 | dunedin
# Processing Record 45 of Set 5 | saquarema
# Processing Record 46 of Set 5 | farmington
# Processing Record 47 of Set 5 | varberg
# Processing Record 48 of Set 5 | tuatapere
# Processing Record 49 of Set 5 | zapolyarnyy
# Processing Record 50 of Set 5 | praia
# Processing Record 1 of Set 6 | pacifica
# Processing Record 2 of Set 6 | grindavik
# Processing Record 3 of Set 6 | namibe
# Processing Record 4 of Set 6 | aitape
# Processing Record 5 of Set 6 | pisco
# Processing Record 6 of Set 6 | westpunt
# City not found. Skipping...
# Processing Record 7 of Set 6 | muros
# Processing Record 8 of Set 6 | taltal
# Processing Record 9 of Set 6 | saint-pierre
# Processing Record 10 of Set 6 | sassandra
# Processing Record 11 of Set 6 | vaitape
# Processing Record 12 of Set 6 | fort nelson
# Processing Record 13 of Set 6 | erenhot
# Processing Record 14 of Set 6 | nanortalik
# Processing Record 15 of Set 6 | yeppoon
# Processing Record 16 of Set 6 | palekh
# Processing Record 17 of Set 6 | port hardy
# Processing Record 18 of Set 6 | maarianhamina
# Processing Record 19 of Set 6 | poshekhonye
# Processing Record 20 of Set 6 | aykhal
# Processing Record 21 of Set 6 | troitskoye
# Processing Record 22 of Set 6 | the pas
# Processing Record 23 of Set 6 | umba
# Processing Record 24 of Set 6 | shingu
# Processing Record 25 of Set 6 | kinango
# Processing Record 26 of Set 6 | sedalia
# Processing Record 27 of Set 6 | cockburn town
# Processing Record 28 of Set 6 | alto araguaia
# Processing Record 29 of Set 6 | artyk
# City not found. Skipping...
# Processing Record 30 of Set 6 | wamba
# Processing Record 31 of Set 6 | cayenne
# Processing Record 32 of Set 6 | mozarlandia
# Processing Record 33 of Set 6 | lhokseumawe
# Processing Record 34 of Set 6 | henties bay
# Processing Record 35 of Set 6 | mamlyutka
# Processing Record 36 of Set 6 | camopi
# Processing Record 37 of Set 6 | atar
# Processing Record 38 of Set 6 | tinskoy
# Processing Record 39 of Set 6 | roros
# Processing Record 40 of Set 6 | lewiston
# Processing Record 41 of Set 6 | katsuura
# Processing Record 42 of Set 6 | velsk
# Processing Record 43 of Set 6 | saldanha
# Processing Record 44 of Set 6 | matagami
# Processing Record 45 of Set 6 | presidencia roque saenz pena
# Processing Record 46 of Set 6 | port shepstone
# Processing Record 47 of Set 6 | tostamaa
# City not found. Skipping...
# Processing Record 48 of Set 6 | suntar
# Processing Record 49 of Set 6 | isla vista
# Processing Record 50 of Set 6 | pacific grove
# Processing Record 1 of Set 7 | toliary
# City not found. Skipping...
# Processing Record 2 of Set 7 | aklavik
# Processing Record 3 of Set 7 | iesolo
# Processing Record 4 of Set 7 | ketchikan
# Processing Record 5 of Set 7 | grand-lahou
# Processing Record 6 of Set 7 | bichura
# Processing Record 7 of Set 7 | koygorodok
# Processing Record 8 of Set 7 | kochki
# Processing Record 9 of Set 7 | hecun
# Processing Record 10 of Set 7 | marzuq
# Processing Record 11 of Set 7 | port lincoln
# Processing Record 12 of Set 7 | nalut
# Processing Record 13 of Set 7 | masvingo
# Processing Record 14 of Set 7 | bambanglipuro
# Processing Record 15 of Set 7 | dourbali
# Processing Record 16 of Set 7 | mogadishu
# Processing Record 17 of Set 7 | zhezkazgan
# Processing Record 18 of Set 7 | hammerfest
# Processing Record 19 of Set 7 | conde
# Processing Record 20 of Set 7 | airai
# Processing Record 21 of Set 7 | oum hadjer
# Processing Record 22 of Set 7 | lannion
# Processing Record 23 of Set 7 | turbat
# Processing Record 24 of Set 7 | butembo
# Processing Record 25 of Set 7 | jaque
# Processing Record 26 of Set 7 | hohhot
# Processing Record 27 of Set 7 | nome
# Processing Record 28 of Set 7 | kantang
# Processing Record 29 of Set 7 | carballo
# Processing Record 30 of Set 7 | sur
# Processing Record 31 of Set 7 | beringovskiy
# Processing Record 32 of Set 7 | dongsheng
# Processing Record 33 of Set 7 | omsukchan
# Processing Record 34 of Set 7 | las lomas
# Processing Record 35 of Set 7 | ulladulla
# Processing Record 36 of Set 7 | mega
# Processing Record 37 of Set 7 | kindu
# Processing Record 38 of Set 7 | tautira
# Processing Record 39 of Set 7 | margate
# Processing Record 40 of Set 7 | eureka
# Processing Record 41 of Set 7 | buariki
# City not found. Skipping...
# Processing Record 42 of Set 7 | roebourne
# Processing Record 43 of Set 7 | beian
# Processing Record 44 of Set 7 | port arthur
# Processing Record 45 of Set 7 | kiunga
# Processing Record 46 of Set 7 | pangnirtung
# Processing Record 47 of Set 7 | norman wells
# Processing Record 48 of Set 7 | skibbereen
# Processing Record 49 of Set 7 | back mountain
# Processing Record 50 of Set 7 | cardinal
# Processing Record 1 of Set 8 | kapiri mposhi
# Processing Record 2 of Set 8 | noshiro
# Processing Record 3 of Set 8 | rawannawi
# City not found. Skipping...
# Processing Record 4 of Set 8 | cherskiy
# Processing Record 5 of Set 8 | natal
# Processing Record 6 of Set 8 | isangel
# Processing Record 7 of Set 8 | boguchany
# Processing Record 8 of Set 8 | manzil salim
# Processing Record 9 of Set 8 | rafraf
# Processing Record 10 of Set 8 | vila franca do campo
# Processing Record 11 of Set 8 | ponta do sol
# Processing Record 12 of Set 8 | hofn
# Processing Record 13 of Set 8 | kavieng
# Processing Record 14 of Set 8 | rawson
# Processing Record 15 of Set 8 | mantenopolis
# Processing Record 16 of Set 8 | ixtapa
# Processing Record 17 of Set 8 | faya
# Processing Record 18 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 19 of Set 8 | nichlaul
# Processing Record 20 of Set 8 | sydney
# Processing Record 21 of Set 8 | najran
# Processing Record 22 of Set 8 | acajutla
# Processing Record 23 of Set 8 | labrea
# Processing Record 24 of Set 8 | mareeba
# Processing Record 25 of Set 8 | verkhnevilyuysk
# Processing Record 26 of Set 8 | vestmannaeyjar
# Processing Record 27 of Set 8 | salalah
# Processing Record 28 of Set 8 | oranjemund
# Processing Record 29 of Set 8 | auki
# Processing Record 30 of Set 8 | peachland
# Processing Record 31 of Set 8 | chauk
# Processing Record 32 of Set 8 | ayna
# Processing Record 33 of Set 8 | cheuskiny
# City not found. Skipping...
# Processing Record 34 of Set 8 | solnechnyy
# Processing Record 35 of Set 8 | othonoi
# City not found. Skipping...
# Processing Record 36 of Set 8 | suez
# Processing Record 37 of Set 8 | kieta
# Processing Record 38 of Set 8 | yerofey pavlovich
# Processing Record 39 of Set 8 | lavrentiya
# Processing Record 40 of Set 8 | mbini
# Processing Record 41 of Set 8 | olaine
# Processing Record 42 of Set 8 | uyuni
# Processing Record 43 of Set 8 | faanui
# Processing Record 44 of Set 8 | sakakah
# Processing Record 45 of Set 8 | kokopo
# Processing Record 46 of Set 8 | honiara
# Processing Record 47 of Set 8 | prestea
# Processing Record 48 of Set 8 | pitimbu
# Processing Record 49 of Set 8 | altay
# Processing Record 50 of Set 8 | gat
# Processing Record 1 of Set 9 | lamu
# Processing Record 2 of Set 9 | kesennuma
# City not found. Skipping...
# Processing Record 3 of Set 9 | ambovombe
# Processing Record 4 of Set 9 | maragogi
# Processing Record 5 of Set 9 | sandur
# Processing Record 6 of Set 9 | guder
# Processing Record 7 of Set 9 | pevek
# Processing Record 8 of Set 9 | xuchang
# Processing Record 9 of Set 9 | tubuala
# Processing Record 10 of Set 9 | goderich
# Processing Record 11 of Set 9 | sao felix do xingu
# Processing Record 12 of Set 9 | mecca
# Processing Record 13 of Set 9 | te anau
# Processing Record 14 of Set 9 | campos
# Processing Record 15 of Set 9 | itarema
# Processing Record 16 of Set 9 | carahue
# Processing Record 17 of Set 9 | tual
# Processing Record 18 of Set 9 | tshikapa
# Processing Record 19 of Set 9 | were ilu
# Processing Record 20 of Set 9 | izhma
# Processing Record 21 of Set 9 | taksimo
# Processing Record 22 of Set 9 | bilma
# Processing Record 23 of Set 9 | kissimmee
# Processing Record 24 of Set 9 | thinadhoo
# Processing Record 25 of Set 9 | buraydah
# Processing Record 26 of Set 9 | adwa
# Processing Record 27 of Set 9 | torgelow
# Processing Record 28 of Set 9 | kaitangata
# Processing Record 29 of Set 9 | mokhsogollokh
# Processing Record 30 of Set 9 | penarroya-pueblonuevo
# Processing Record 31 of Set 9 | ahipara
# Processing Record 32 of Set 9 | taoudenni
# Processing Record 33 of Set 9 | chitral
# Processing Record 34 of Set 9 | awbari
# Processing Record 35 of Set 9 | dombarovskiy
# Processing Record 36 of Set 9 | meulaboh
# Processing Record 37 of Set 9 | staunton
# Processing Record 38 of Set 9 | yenagoa
# Processing Record 39 of Set 9 | ascension
# Processing Record 40 of Set 9 | narsaq
# Processing Record 41 of Set 9 | ancud
# Processing Record 42 of Set 9 | correntina
# Processing Record 43 of Set 9 | alyangula
# Processing Record 44 of Set 9 | sorland
# Processing Record 45 of Set 9 | katsiveli
# City not found. Skipping...
# Processing Record 46 of Set 9 | molepolole
# Processing Record 47 of Set 9 | lincoln
# Processing Record 48 of Set 9 | padang
# Processing Record 49 of Set 9 | santa cruz
# Processing Record 50 of Set 9 | nerchinskiy zavod
# Processing Record 1 of Set 10 | razole
# Processing Record 2 of Set 10 | tsabong
# Processing Record 3 of Set 10 | giyani
# Processing Record 4 of Set 10 | araouane
# Processing Record 5 of Set 10 | saryg-sep
# Processing Record 6 of Set 10 | tessalit
# Processing Record 7 of Set 10 | mardin
# Processing Record 8 of Set 10 | amderma
# City not found. Skipping...
# Processing Record 9 of Set 10 | bontang
# Processing Record 10 of Set 10 | letenye
# Processing Record 11 of Set 10 | vilnius
# Processing Record 12 of Set 10 | amapa
# Processing Record 13 of Set 10 | acapulco
# Processing Record 14 of Set 10 | hualmay
# Processing Record 15 of Set 10 | kailua
# Processing Record 16 of Set 10 | pozo colorado
# Processing Record 17 of Set 10 | ninghai
# Processing Record 18 of Set 10 | aberdeen
# Processing Record 19 of Set 10 | inyonga
# Processing Record 20 of Set 10 | panlaitan
# Processing Record 21 of Set 10 | gikongoro
# Processing Record 22 of Set 10 | arlit
# Processing Record 23 of Set 10 | maghama
# City not found. Skipping...
# Processing Record 24 of Set 10 | minsk
# Processing Record 25 of Set 10 | arsenyev
# Processing Record 26 of Set 10 | freeport
# Processing Record 27 of Set 10 | bac lieu
# Processing Record 28 of Set 10 | vanavara
# Processing Record 29 of Set 10 | maniitsoq
# Processing Record 30 of Set 10 | tuy hoa
# Processing Record 31 of Set 10 | mykhaylivka
# Processing Record 32 of Set 10 | pouebo
# Processing Record 33 of Set 10 | mathbaria
# Processing Record 34 of Set 10 | ust-ishim
# Processing Record 35 of Set 10 | sulphur springs
# Processing Record 36 of Set 10 | tres picos
# Processing Record 37 of Set 10 | mahadday weyne
# City not found. Skipping...
# Processing Record 38 of Set 10 | maceio
# Processing Record 39 of Set 10 | severnoye
# Processing Record 40 of Set 10 | ifanadiana
# Processing Record 41 of Set 10 | vallenar
# Processing Record 42 of Set 10 | krasnovishersk
# Processing Record 43 of Set 10 | kollumerland
# City not found. Skipping...
# Processing Record 44 of Set 10 | weston-super-mare
# Processing Record 45 of Set 10 | lata
# Processing Record 46 of Set 10 | buala
# Processing Record 47 of Set 10 | aktash
# Processing Record 48 of Set 10 | necochea
# Processing Record 49 of Set 10 | shakawe
# Processing Record 50 of Set 10 | kerrville
# Processing Record 1 of Set 11 | rio gallegos
# Processing Record 2 of Set 11 | gao
# Processing Record 3 of Set 11 | slave lake
# Processing Record 4 of Set 11 | gerede
# Processing Record 5 of Set 11 | craig
# Processing Record 6 of Set 11 | canillo
# Processing Record 7 of Set 11 | sitka
# Processing Record 8 of Set 11 | yerbogachen
# Processing Record 9 of Set 11 | iranshahr
# Processing Record 10 of Set 11 | dubovskoye
# Processing Record 11 of Set 11 | bone
# Processing Record 12 of Set 11 | boden
# Processing Record 13 of Set 11 | tayshet
# Processing Record 14 of Set 11 | canto do buriti
# Processing Record 15 of Set 11 | walvis bay
# Processing Record 16 of Set 11 | minab
# Processing Record 17 of Set 11 | del carmen
# Processing Record 18 of Set 11 | oussouye
# Processing Record 19 of Set 11 | gandajika
# Processing Record 20 of Set 11 | salamiyah
# Processing Record 21 of Set 11 | yumen
# Processing Record 22 of Set 11 | sitio novo do tocantins
# Processing Record 23 of Set 11 | oksbol
# Processing Record 24 of Set 11 | kastamonu
# Processing Record 25 of Set 11 | nhulunbuy
# Processing Record 26 of Set 11 | batsfjord
# Processing Record 27 of Set 11 | samalaeulu
# City not found. Skipping...
# Processing Record 28 of Set 11 | key largo
# Processing Record 29 of Set 11 | shitanjing
# Processing Record 30 of Set 11 | garowe
# Processing Record 31 of Set 11 | cabra
# Processing Record 32 of Set 11 | aketi
# Processing Record 33 of Set 11 | vanimo
# Processing Record 34 of Set 11 | naze
# Processing Record 35 of Set 11 | angoche
# Processing Record 36 of Set 11 | katherine
# Processing Record 37 of Set 11 | sosnovskoye
# Processing Record 38 of Set 11 | kavaratti
# Processing Record 39 of Set 11 | hihifo
# City not found. Skipping...
# Processing Record 40 of Set 11 | gamba
# Processing Record 41 of Set 11 | zykovo
# Processing Record 42 of Set 11 | puerto rico
# Processing Record 43 of Set 11 | la reforma
# Processing Record 44 of Set 11 | castlegar
# Processing Record 45 of Set 11 | sao joao da ponte
# Processing Record 46 of Set 11 | hwange
# Processing Record 47 of Set 11 | sao joao da barra
# Processing Record 48 of Set 11 | dudinka
# Processing Record 49 of Set 11 | blacksburg
# Processing Record 50 of Set 11 | kella
# Processing Record 1 of Set 12 | san joaquin
# Processing Record 2 of Set 12 | tartus
# Processing Record 3 of Set 12 | kazminskoye
# City not found. Skipping...
# Processing Record 4 of Set 12 | si sa ket
# Processing Record 5 of Set 12 | codajas
# Processing Record 6 of Set 12 | tulun
# Processing Record 7 of Set 12 | peruibe
# Processing Record 8 of Set 12 | astana
# Processing Record 9 of Set 12 | loreto
# Processing Record 10 of Set 12 | nelson bay
# Processing Record 11 of Set 12 | zyryanskoye
# Processing Record 12 of Set 12 | phumi samraong
# City not found. Skipping...
# Processing Record 13 of Set 12 | pontianak
# Processing Record 14 of Set 12 | tokur
# Processing Record 15 of Set 12 | kirakira
# Processing Record 16 of Set 12 | asau
# Processing Record 17 of Set 12 | avera
# Processing Record 18 of Set 12 | makakilo city
# Processing Record 19 of Set 12 | stranda
# Processing Record 20 of Set 12 | hanzhong
# Processing Record 21 of Set 12 | champasak
# Processing Record 22 of Set 12 | galesong
# Processing Record 23 of Set 12 | marcona
# City not found. Skipping...
# Processing Record 24 of Set 12 | cumaribo
# City not found. Skipping...
# Processing Record 25 of Set 12 | hays
# Processing Record 26 of Set 12 | weligama
# Processing Record 27 of Set 12 | sambava
# Processing Record 28 of Set 12 | jalu
# Processing Record 29 of Set 12 | deniliquin
# Processing Record 30 of Set 12 | solovetskiy
# City not found. Skipping...
# Processing Record 31 of Set 12 | petrykiv
# Processing Record 32 of Set 12 | pueblo rico
# Processing Record 33 of Set 12 | southbridge
# Processing Record 34 of Set 12 | gravdal
# Processing Record 35 of Set 12 | fomboni
# Processing Record 36 of Set 12 | vardo
# Processing Record 37 of Set 12 | chabahar
# Processing Record 38 of Set 12 | saint-francois
# Processing Record 39 of Set 12 | sao filipe
# Processing Record 40 of Set 12 | caravelas
# Processing Record 41 of Set 12 | ossora
# Processing Record 42 of Set 12 | fairbanks
# Processing Record 43 of Set 12 | kuche
# City not found. Skipping...
# Processing Record 44 of Set 12 | dalbandin
# Processing Record 45 of Set 12 | nantucket
# Processing Record 46 of Set 12 | hassleholm
# Processing Record 47 of Set 12 | khani
# Processing Record 48 of Set 12 | saleaula
# City not found. Skipping...
# Processing Record 49 of Set 12 | raudeberg
# Processing Record 50 of Set 12 | nagato
# Processing Record 1 of Set 13 | dzhusaly
# City not found. Skipping...
# Processing Record 2 of Set 13 | boddam
# Processing Record 3 of Set 13 | san vicente
# Processing Record 4 of Set 13 | moose factory
# Processing Record 5 of Set 13 | vestmanna
# Processing Record 6 of Set 13 | rohtak
# Processing Record 7 of Set 13 | opuwo
# Processing Record 8 of Set 13 | phan thiet
# Processing Record 9 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 10 of Set 13 | kandrian
# Processing Record 11 of Set 13 | richards bay
# Processing Record 12 of Set 13 | mungwi
# Processing Record 13 of Set 13 | inirida
# Processing Record 14 of Set 13 | terlizzi
# Processing Record 15 of Set 13 | mrirt
# City not found. Skipping...
# Processing Record 16 of Set 13 | ghanzi
# Processing Record 17 of Set 13 | scottsburgh
# City not found. Skipping...
# Processing Record 18 of Set 13 | yulara
# Processing Record 19 of Set 13 | iqaluit
# Processing Record 20 of Set 13 | sangar
# Processing Record 21 of Set 13 | mweka
# Processing Record 22 of Set 13 | aporawan
# City not found. Skipping...
# Processing Record 23 of Set 13 | lazaro cardenas
# Processing Record 24 of Set 13 | phan rang
# City not found. Skipping...
# Processing Record 25 of Set 13 | andreapol
# Processing Record 26 of Set 13 | kruisfontein
# Processing Record 27 of Set 13 | palmer
# Processing Record 28 of Set 13 | kapit
# Processing Record 29 of Set 13 | amuntai
# Processing Record 30 of Set 13 | praya
# Processing Record 31 of Set 13 | balimo
# City not found. Skipping...
# Processing Record 32 of Set 13 | streletskoye
# Processing Record 33 of Set 13 | bajo baudo
# City not found. Skipping...
# Processing Record 34 of Set 13 | flinders
# Processing Record 35 of Set 13 | petrolina de goias
# Processing Record 36 of Set 13 | nishihara
# Processing Record 37 of Set 13 | tokonou
# Processing Record 38 of Set 13 | novyy urengoy
# Processing Record 39 of Set 13 | srbobran
# Processing Record 40 of Set 13 | mattru
# Processing Record 41 of Set 13 | crab hill
# City not found. Skipping...
# Processing Record 42 of Set 13 | carnduff
# Processing Record 43 of Set 13 | tucurui
# Processing Record 44 of Set 13 | barcelos
# Processing Record 45 of Set 13 | jumla
# Processing Record 46 of Set 13 | jiuquan
# Processing Record 47 of Set 13 | mayo
# Processing Record 48 of Set 13 | qena
# Processing Record 49 of Set 13 | jutai
# Processing Record 50 of Set 13 | innisfail
# Processing Record 1 of Set 14 | sibolga
# Processing Record 2 of Set 14 | oktyabrskiy
# Processing Record 3 of Set 14 | guayaramerin
# Processing Record 4 of Set 14 | barentu
# Processing Record 5 of Set 14 | taburi
# City not found. Skipping...
# Processing Record 6 of Set 14 | villanueva de la serena
# Processing Record 7 of Set 14 | tagusao
# Processing Record 8 of Set 14 | gambela
# Processing Record 9 of Set 14 | palmares do sul
# Processing Record 10 of Set 14 | brisbane
# Processing Record 11 of Set 14 | soledade
# Processing Record 12 of Set 14 | akyab
# Processing Record 13 of Set 14 | kolokani
# Processing Record 14 of Set 14 | puerto maldonado
# Processing Record 15 of Set 14 | odienne
# Processing Record 16 of Set 14 | rocafuerte
# Processing Record 17 of Set 14 | nuevo progreso
# Processing Record 18 of Set 14 | ruteng
# Processing Record 19 of Set 14 | sterling
# Processing Record 20 of Set 14 | port hedland
# Processing Record 21 of Set 14 | dengzhou
# Processing Record 22 of Set 14 | nicoya
# Processing Record 23 of Set 14 | storsteinnes
# Processing Record 24 of Set 14 | rovenki
# Processing Record 25 of Set 14 | choya
# Processing Record 26 of Set 14 | louisbourg
# City not found. Skipping...
# Processing Record 27 of Set 14 | halalo
# City not found. Skipping...
# Processing Record 28 of Set 14 | amurzet
# Processing Record 29 of Set 14 | quatre cocos
# Processing Record 30 of Set 14 | yangmei
# Processing Record 31 of Set 14 | marsa matruh
# Processing Record 32 of Set 14 | gurgan
# City not found. Skipping...
# Processing Record 33 of Set 14 | grojec
# Processing Record 34 of Set 14 | ayorou
# Processing Record 35 of Set 14 | nouadhibou
# Processing Record 36 of Set 14 | abiy adi
# City not found. Skipping...
# Processing Record 37 of Set 14 | nakusp
# Processing Record 38 of Set 14 | charters towers
# Processing Record 39 of Set 14 | attawapiskat
# City not found. Skipping...
# Processing Record 40 of Set 14 | mahalapye
# Processing Record 41 of Set 14 | khakhea
# Processing Record 42 of Set 14 | celano
# Processing Record 43 of Set 14 | la peca
# Processing Record 44 of Set 14 | ijui
# Processing Record 45 of Set 14 | sistranda
# Processing Record 46 of Set 14 | los llanos de aridane
# Processing Record 47 of Set 14 | liwale
# Processing Record 48 of Set 14 | tevaitoa
# Processing Record 49 of Set 14 | konotop
# Processing Record 50 of Set 14 | honningsvag
# Processing Record 1 of Set 15 | stutterheim
# Processing Record 2 of Set 15 | salinopolis
# Processing Record 3 of Set 15 | daxian
# City not found. Skipping...
# Processing Record 4 of Set 15 | virginia beach
# Processing Record 5 of Set 15 | odweyne
# Processing Record 6 of Set 15 | maharajganj
# Processing Record 7 of Set 15 | bauta
# Processing Record 8 of Set 15 | anadyr
# Processing Record 9 of Set 15 | batken
# Processing Record 10 of Set 15 | vila
# Processing Record 11 of Set 15 | goundam
# Processing Record 12 of Set 15 | waddan
# Processing Record 13 of Set 15 | yinchuan
# Processing Record 14 of Set 15 | saint-augustin
# Processing Record 15 of Set 15 | esmeraldas
# Processing Record 16 of Set 15 | portlethen
# Processing Record 17 of Set 15 | obo
# Processing Record 18 of Set 15 | olafsvik
# Processing Record 19 of Set 15 | pervomayskoye
# Processing Record 20 of Set 15 | aksarka
# Processing Record 21 of Set 15 | nuuk
# Processing Record 22 of Set 15 | alghero
# Processing Record 23 of Set 15 | ovalle
# Processing Record 24 of Set 15 | kimbe
# Processing Record 25 of Set 15 | atherton
# Processing Record 26 of Set 15 | rungata
# City not found. Skipping...
# Processing Record 27 of Set 15 | sisimiut
# Processing Record 28 of Set 15 | taquara
# Processing Record 29 of Set 15 | iquique
# Processing Record 30 of Set 15 | kiama
# Processing Record 31 of Set 15 | unai
# Processing Record 32 of Set 15 | osmena
# Processing Record 33 of Set 15 | hobyo
# Processing Record 34 of Set 15 | qasigiannguit
# Processing Record 35 of Set 15 | aragarcas
# Processing Record 36 of Set 15 | roma
# Processing Record 37 of Set 15 | hinton
# Processing Record 38 of Set 15 | antalaha
# Processing Record 39 of Set 15 | cedar city
# Processing Record 40 of Set 15 | andros town
# Processing Record 41 of Set 15 | atasu
# Processing Record 42 of Set 15 | kanjiza
# Processing Record 43 of Set 15 | tortoli
# Processing Record 44 of Set 15 | makubetsu
# Processing Record 45 of Set 15 | bathsheba
# Processing Record 46 of Set 15 | tongling
# Processing Record 47 of Set 15 | tarare
# Processing Record 48 of Set 15 | samarai
# Processing Record 49 of Set 15 | sobolevo
# Processing Record 50 of Set 15 | porto novo
# Processing Record 1 of Set 16 | biloela
# Processing Record 2 of Set 16 | brae
# Processing Record 3 of Set 16 | jalingo
# Processing Record 4 of Set 16 | kamenskoye
# City not found. Skipping...
# Processing Record 5 of Set 16 | staraya stanitsa
# Processing Record 6 of Set 16 | limbang
# Processing Record 7 of Set 16 | obihiro
# Processing Record 8 of Set 16 | batemans bay
# Processing Record 9 of Set 16 | ambilobe
# Processing Record 10 of Set 16 | inhambane
# Processing Record 11 of Set 16 | pochutla
# Processing Record 12 of Set 16 | mehran
# Processing Record 13 of Set 16 | vangaindrano
# Processing Record 14 of Set 16 | zhigansk
# Processing Record 15 of Set 16 | eastbourne
# Processing Record 16 of Set 16 | veryina
# City not found. Skipping...
# Processing Record 17 of Set 16 | shestakovo
# Processing Record 18 of Set 16 | kuhdasht
# Processing Record 19 of Set 16 | kaniama
# Processing Record 20 of Set 16 | eldikan
# City not found. Skipping...
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Get how many cities are in our array of dictionaries
len(city_data)
# Out:
# 702

# %%
# Convert array of dictionaries into a DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#              City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0           Lodja  -3.48   23.43     70.97        88           1        1.48
# 1          Bethel  41.37  -73.41     53.01        81          90        6.93
# 2           Kapaa  22.08 -159.32     77.00        83          40       14.99
# 3         Ushuaia -54.80  -68.30     57.20        33          40       19.46
# 4        Khatanga  71.97  102.50    -23.76        85         100       10.96
# 5          Evensk  61.95  159.23    -30.57        70           0        7.43
# 6          Tadine -21.55  167.88     77.70        72         100        5.70
# 7  Ribeira Grande  38.52  -28.70     55.40        76          40       16.11
# 8           Vaini -21.20 -175.20     78.80        94          20        4.70
# 9       Cape Town -33.93   18.42     69.01        77           0        6.93
#
#   Country Current Description
# 0      CD           clear sky
# 1      US     overcast clouds
# 2      US    scattered clouds
# 3      AR         shower rain
# 4      RU     overcast clouds
# 5      RU           clear sky
# 6      NC     overcast clouds
# 7      PT    scattered clouds
# 8      TO          few clouds
# 9      ZA           clear sky

# %%
# Reorder the columns.
new_column_order = ["City", "Country", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#              City Country    Lat     Lng  Max Temp  Humidity  Cloudiness  \
# 0           Lodja      CD  -3.48   23.43     70.97        88           1
# 1          Bethel      US  41.37  -73.41     53.01        81          90
# 2           Kapaa      US  22.08 -159.32     77.00        83          40
# 3         Ushuaia      AR -54.80  -68.30     57.20        33          40
# 4        Khatanga      RU  71.97  102.50    -23.76        85         100
# 5          Evensk      RU  61.95  159.23    -30.57        70           0
# 6          Tadine      NC -21.55  167.88     77.70        72         100
# 7  Ribeira Grande      PT  38.52  -28.70     55.40        76          40
# 8           Vaini      TO -21.20 -175.20     78.80        94          20
# 9       Cape Town      ZA -33.93   18.42     69.01        77           0
#
#    Wind Speed Current Description
# 0        1.48           clear sky
# 1        6.93     overcast clouds
# 2       14.99    scattered clouds
# 3       19.46         shower rain
# 4       10.96     overcast clouds
# 5        7.43           clear sky
# 6        5.70     overcast clouds
# 7       16.11    scattered clouds
# 8        4.70          few clouds
# 9        6.93           clear sky

# %%
# Create the output file (csv).
output_data_file = "WeatherPy_Database.csv"

# Export the city_data to the output file.
city_data_df.to_csv(output_data_file, index_label="City ID")
