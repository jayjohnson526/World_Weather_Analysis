# %%
# Import dependencies. 
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests

# Import the API key.
from config import weather_api_key

# Import the datetime module from the datetime library.
from datetime import datetime

# %%
# Create a set of random latitude and lognitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and lognitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    
    # If the city is unique, then we will add it to the list of cities.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 633

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3e5efb6fe89b37682abebc20c98bd6c3

# %%
# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in our list.
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        
    # Create endpoint URL with each city
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
# Run an API for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                         "Lat": city_lat,
                         "Lng": city_lng,
                         "Max Temp": city_max_temp,
                         "Humidity": city_humidity,
                         "Cloudiness": city_clouds,
                         "Wind Speed": city_wind,
                         "Country": city_country,
                         "Date": city_date})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
        
# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Processing Record 1 of Set 1 | barrow
# Processing Record 2 of Set 1 | linfen
# Processing Record 3 of Set 1 | high level
# Processing Record 4 of Set 1 | punta arenas
# Processing Record 5 of Set 1 | bredasdorp
# Processing Record 6 of Set 1 | coquimbo
# Processing Record 7 of Set 1 | luderitz
# Processing Record 8 of Set 1 | kodiak
# Processing Record 9 of Set 1 | gonaives
# Processing Record 10 of Set 1 | oranjemund
# Processing Record 11 of Set 1 | yellowknife
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | qaanaaq
# Processing Record 14 of Set 1 | yulara
# Processing Record 15 of Set 1 | albany
# Processing Record 16 of Set 1 | halifax
# Processing Record 17 of Set 1 | atuona
# Processing Record 18 of Set 1 | mar del plata
# Processing Record 19 of Set 1 | grindavik
# Processing Record 20 of Set 1 | castro
# Processing Record 21 of Set 1 | raga
# Processing Record 22 of Set 1 | mataura
# Processing Record 23 of Set 1 | ushuaia
# Processing Record 24 of Set 1 | makakilo city
# Processing Record 25 of Set 1 | nikolskoye
# Processing Record 26 of Set 1 | chirongui
# Processing Record 27 of Set 1 | airai
# Processing Record 28 of Set 1 | port alfred
# Processing Record 29 of Set 1 | torbay
# Processing Record 30 of Set 1 | killarney
# Processing Record 31 of Set 1 | geraldton
# Processing Record 32 of Set 1 | kapaa
# Processing Record 33 of Set 1 | deep river
# Processing Record 34 of Set 1 | cape town
# Processing Record 35 of Set 1 | cam ranh
# Processing Record 36 of Set 1 | san benito
# Processing Record 37 of Set 1 | bluff
# Processing Record 38 of Set 1 | longyearbyen
# Processing Record 39 of Set 1 | pevek
# Processing Record 40 of Set 1 | hobart
# Processing Record 41 of Set 1 | rosarito
# Processing Record 42 of Set 1 | rio gallegos
# Processing Record 43 of Set 1 | avarua
# Processing Record 44 of Set 1 | dikson
# Processing Record 45 of Set 1 | oxford
# Processing Record 46 of Set 1 | boa vista
# Processing Record 47 of Set 1 | zyryanka
# Processing Record 48 of Set 1 | port lincoln
# Processing Record 49 of Set 1 | mae sai
# Processing Record 50 of Set 1 | ancud
# Processing Record 1 of Set 2 | cedar lake
# Processing Record 2 of Set 2 | opuwo
# Processing Record 3 of Set 2 | upernavik
# Processing Record 4 of Set 2 | bengkulu
# Processing Record 5 of Set 2 | arraial do cabo
# Processing Record 6 of Set 2 | grand river south east
# City not found. Skipping...
# Processing Record 7 of Set 2 | new norfolk
# Processing Record 8 of Set 2 | port moresby
# Processing Record 9 of Set 2 | vaini
# Processing Record 10 of Set 2 | hilo
# Processing Record 11 of Set 2 | grand gaube
# Processing Record 12 of Set 2 | vardo
# Processing Record 13 of Set 2 | port hardy
# Processing Record 14 of Set 2 | buala
# Processing Record 15 of Set 2 | kruisfontein
# Processing Record 16 of Set 2 | khromtau
# Processing Record 17 of Set 2 | cabo san lucas
# Processing Record 18 of Set 2 | beyneu
# Processing Record 19 of Set 2 | georgetown
# Processing Record 20 of Set 2 | pantai remis
# Processing Record 21 of Set 2 | ituporanga
# Processing Record 22 of Set 2 | chuy
# Processing Record 23 of Set 2 | epe
# Processing Record 24 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 25 of Set 2 | sorong
# Processing Record 26 of Set 2 | severo-kurilsk
# Processing Record 27 of Set 2 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 28 of Set 2 | narsaq
# Processing Record 29 of Set 2 | lakes entrance
# Processing Record 30 of Set 2 | hobyo
# Processing Record 31 of Set 2 | shulan
# Processing Record 32 of Set 2 | seoul
# Processing Record 33 of Set 2 | shiyan
# Processing Record 34 of Set 2 | batagay-alyta
# Processing Record 35 of Set 2 | iqaluit
# Processing Record 36 of Set 2 | broken hill
# Processing Record 37 of Set 2 | davila
# Processing Record 38 of Set 2 | oga
# Processing Record 39 of Set 2 | flinders
# Processing Record 40 of Set 2 | bassano
# Processing Record 41 of Set 2 | jimma
# Processing Record 42 of Set 2 | esperance
# Processing Record 43 of Set 2 | mastung
# Processing Record 44 of Set 2 | pala
# Processing Record 45 of Set 2 | taolanaro
# City not found. Skipping...
# Processing Record 46 of Set 2 | nome
# Processing Record 47 of Set 2 | tiksi
# Processing Record 48 of Set 2 | meulaboh
# Processing Record 49 of Set 2 | kirakira
# Processing Record 50 of Set 2 | isangel
# Processing Record 1 of Set 3 | lolua
# City not found. Skipping...
# Processing Record 2 of Set 3 | abu jubayhah
# City not found. Skipping...
# Processing Record 3 of Set 3 | mahebourg
# Processing Record 4 of Set 3 | carnarvon
# Processing Record 5 of Set 3 | mitu
# Processing Record 6 of Set 3 | cartagena
# Processing Record 7 of Set 3 | ribera
# Processing Record 8 of Set 3 | gobabis
# Processing Record 9 of Set 3 | busselton
# Processing Record 10 of Set 3 | nanortalik
# Processing Record 11 of Set 3 | saleaula
# City not found. Skipping...
# Processing Record 12 of Set 3 | sakaiminato
# Processing Record 13 of Set 3 | puerto ayora
# Processing Record 14 of Set 3 | ostrovnoy
# Processing Record 15 of Set 3 | krasnoselkup
# Processing Record 16 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 17 of Set 3 | ambon
# Processing Record 18 of Set 3 | eldikan
# City not found. Skipping...
# Processing Record 19 of Set 3 | butaritari
# Processing Record 20 of Set 3 | richards bay
# Processing Record 21 of Set 3 | biloela
# Processing Record 22 of Set 3 | hanko
# Processing Record 23 of Set 3 | morondava
# Processing Record 24 of Set 3 | healdsburg
# Processing Record 25 of Set 3 | mocuba
# Processing Record 26 of Set 3 | the valley
# Processing Record 27 of Set 3 | hermanus
# Processing Record 28 of Set 3 | xam nua
# Processing Record 29 of Set 3 | chokurdakh
# Processing Record 30 of Set 3 | turtas
# Processing Record 31 of Set 3 | vangaindrano
# Processing Record 32 of Set 3 | ahome
# Processing Record 33 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 34 of Set 3 | praia da vitoria
# Processing Record 35 of Set 3 | cap malheureux
# Processing Record 36 of Set 3 | saskylakh
# Processing Record 37 of Set 3 | nato
# Processing Record 38 of Set 3 | east london
# Processing Record 39 of Set 3 | roma
# Processing Record 40 of Set 3 | petropavlovsk-kamchatskiy
# Processing Record 41 of Set 3 | tuktoyaktuk
# Processing Record 42 of Set 3 | balaipungut
# Processing Record 43 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 44 of Set 3 | inuvik
# Processing Record 45 of Set 3 | cayenne
# Processing Record 46 of Set 3 | houma
# Processing Record 47 of Set 3 | venice
# Processing Record 48 of Set 3 | thompson
# Processing Record 49 of Set 3 | joshimath
# Processing Record 50 of Set 3 | maningrida
# Processing Record 1 of Set 4 | kupang
# Processing Record 2 of Set 4 | esil
# Processing Record 3 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 4 of Set 4 | sungaipenuh
# Processing Record 5 of Set 4 | fereydun kenar
# Processing Record 6 of Set 4 | college
# Processing Record 7 of Set 4 | port-gentil
# Processing Record 8 of Set 4 | husavik
# Processing Record 9 of Set 4 | coron
# Processing Record 10 of Set 4 | jamestown
# Processing Record 11 of Set 4 | olinda
# Processing Record 12 of Set 4 | grootfontein
# Processing Record 13 of Set 4 | moroni
# Processing Record 14 of Set 4 | sekoma
# Processing Record 15 of Set 4 | dali
# Processing Record 16 of Set 4 | la ronge
# Processing Record 17 of Set 4 | dingle
# Processing Record 18 of Set 4 | at-bashi
# Processing Record 19 of Set 4 | lahan
# Processing Record 20 of Set 4 | xinqing
# Processing Record 21 of Set 4 | bama
# Processing Record 22 of Set 4 | pisco
# Processing Record 23 of Set 4 | vila franca do campo
# Processing Record 24 of Set 4 | kloulklubed
# Processing Record 25 of Set 4 | stuttgart
# Processing Record 26 of Set 4 | kavieng
# Processing Record 27 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 28 of Set 4 | micheweni
# Processing Record 29 of Set 4 | aklavik
# Processing Record 30 of Set 4 | sorland
# Processing Record 31 of Set 4 | dhidhdhoo
# Processing Record 32 of Set 4 | umm kaddadah
# Processing Record 33 of Set 4 | registro
# Processing Record 34 of Set 4 | shepetivka
# Processing Record 35 of Set 4 | kieta
# Processing Record 36 of Set 4 | brae
# Processing Record 37 of Set 4 | minab
# Processing Record 38 of Set 4 | taoudenni
# Processing Record 39 of Set 4 | abu samrah
# Processing Record 40 of Set 4 | batagay
# Processing Record 41 of Set 4 | susuman
# Processing Record 42 of Set 4 | solnechnyy
# Processing Record 43 of Set 4 | nyurba
# Processing Record 44 of Set 4 | inhambane
# Processing Record 45 of Set 4 | santa isabel do rio negro
# Processing Record 46 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 47 of Set 4 | wajid
# Processing Record 48 of Set 4 | ponta delgada
# Processing Record 49 of Set 4 | namibe
# Processing Record 50 of Set 4 | san patricio
# Processing Record 1 of Set 5 | norman wells
# Processing Record 2 of Set 5 | ahuimanu
# Processing Record 3 of Set 5 | ribeira grande
# Processing Record 4 of Set 5 | korem
# Processing Record 5 of Set 5 | chahuites
# Processing Record 6 of Set 5 | hovd
# Processing Record 7 of Set 5 | pangnirtung
# Processing Record 8 of Set 5 | bondo
# Processing Record 9 of Set 5 | middle island
# Processing Record 10 of Set 5 | vestmanna
# Processing Record 11 of Set 5 | vostok
# Processing Record 12 of Set 5 | sirjan
# Processing Record 13 of Set 5 | yurimaguas
# Processing Record 14 of Set 5 | cidreira
# Processing Record 15 of Set 5 | sitka
# Processing Record 16 of Set 5 | changping
# Processing Record 17 of Set 5 | fevralsk
# City not found. Skipping...
# Processing Record 18 of Set 5 | hamilton
# Processing Record 19 of Set 5 | fort wellington
# Processing Record 20 of Set 5 | saint-francois
# Processing Record 21 of Set 5 | santa cruz verapaz
# Processing Record 22 of Set 5 | mys shmidta
# City not found. Skipping...
# Processing Record 23 of Set 5 | ilulissat
# Processing Record 24 of Set 5 | kijang
# Processing Record 25 of Set 5 | lorengau
# Processing Record 26 of Set 5 | bereda
# Processing Record 27 of Set 5 | talcahuano
# Processing Record 28 of Set 5 | faanui
# Processing Record 29 of Set 5 | takaungu
# Processing Record 30 of Set 5 | nelson bay
# Processing Record 31 of Set 5 | topolobampo
# Processing Record 32 of Set 5 | nicoya
# Processing Record 33 of Set 5 | lagoa
# Processing Record 34 of Set 5 | ishigaki
# Processing Record 35 of Set 5 | shache
# Processing Record 36 of Set 5 | ponta do sol
# Processing Record 37 of Set 5 | beringovskiy
# Processing Record 38 of Set 5 | vila
# Processing Record 39 of Set 5 | zhezkazgan
# Processing Record 40 of Set 5 | bambous virieux
# Processing Record 41 of Set 5 | codrington
# Processing Record 42 of Set 5 | alofi
# Processing Record 43 of Set 5 | sisimiut
# Processing Record 44 of Set 5 | choszczno
# Processing Record 45 of Set 5 | afsin
# Processing Record 46 of Set 5 | shaoyang
# Processing Record 47 of Set 5 | huancabamba
# Processing Record 48 of Set 5 | kenai
# Processing Record 49 of Set 5 | hasaki
# Processing Record 50 of Set 5 | charters towers
# Processing Record 1 of Set 6 | uarini
# Processing Record 2 of Set 6 | galesong
# Processing Record 3 of Set 6 | shimoda
# Processing Record 4 of Set 6 | port blair
# Processing Record 5 of Set 6 | mezhdurechensk
# Processing Record 6 of Set 6 | constitucion
# Processing Record 7 of Set 6 | champerico
# Processing Record 8 of Set 6 | khatanga
# Processing Record 9 of Set 6 | nizhniy odes
# Processing Record 10 of Set 6 | souillac
# Processing Record 11 of Set 6 | saint-augustin
# Processing Record 12 of Set 6 | jiayuguan
# Processing Record 13 of Set 6 | zhangjiakou
# Processing Record 14 of Set 6 | saint-joseph
# Processing Record 15 of Set 6 | puerto escondido
# Processing Record 16 of Set 6 | talara
# Processing Record 17 of Set 6 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 18 of Set 6 | tiznit
# Processing Record 19 of Set 6 | palanga
# Processing Record 20 of Set 6 | clyde river
# Processing Record 21 of Set 6 | kaitangata
# Processing Record 22 of Set 6 | dodge city
# Processing Record 23 of Set 6 | mountain home
# Processing Record 24 of Set 6 | san quintin
# Processing Record 25 of Set 6 | nizhneyansk
# City not found. Skipping...
# Processing Record 26 of Set 6 | churapcha
# Processing Record 27 of Set 6 | portland
# Processing Record 28 of Set 6 | lebu
# Processing Record 29 of Set 6 | necochea
# Processing Record 30 of Set 6 | tecoman
# Processing Record 31 of Set 6 | viedma
# Processing Record 32 of Set 6 | khelyulya
# Processing Record 33 of Set 6 | melfi
# Processing Record 34 of Set 6 | saint george
# Processing Record 35 of Set 6 | miskolc
# Processing Record 36 of Set 6 | ballina
# Processing Record 37 of Set 6 | palabuhanratu
# City not found. Skipping...
# Processing Record 38 of Set 6 | videira
# Processing Record 39 of Set 6 | magadan
# Processing Record 40 of Set 6 | mindelo
# Processing Record 41 of Set 6 | paamiut
# Processing Record 42 of Set 6 | zhanaozen
# Processing Record 43 of Set 6 | tasiilaq
# Processing Record 44 of Set 6 | ca mau
# Processing Record 45 of Set 6 | hithadhoo
# Processing Record 46 of Set 6 | kampot
# Processing Record 47 of Set 6 | marovoay
# Processing Record 48 of Set 6 | tahoua
# Processing Record 49 of Set 6 | broome
# Processing Record 50 of Set 6 | tsihombe
# City not found. Skipping...
# Processing Record 1 of Set 7 | marcona
# City not found. Skipping...
# Processing Record 2 of Set 7 | mount isa
# Processing Record 3 of Set 7 | kaeo
# Processing Record 4 of Set 7 | vila velha
# Processing Record 5 of Set 7 | marsh harbour
# Processing Record 6 of Set 7 | strelka
# Processing Record 7 of Set 7 | gornopravdinsk
# Processing Record 8 of Set 7 | thornbury
# Processing Record 9 of Set 7 | saint-philippe
# Processing Record 10 of Set 7 | hambantota
# Processing Record 11 of Set 7 | san cristobal
# Processing Record 12 of Set 7 | sakakah
# Processing Record 13 of Set 7 | quatre cocos
# Processing Record 14 of Set 7 | matara
# Processing Record 15 of Set 7 | bakchar
# Processing Record 16 of Set 7 | anito
# Processing Record 17 of Set 7 | cocorit
# Processing Record 18 of Set 7 | superior
# Processing Record 19 of Set 7 | akhmim
# Processing Record 20 of Set 7 | moose factory
# Processing Record 21 of Set 7 | aswan
# Processing Record 22 of Set 7 | benghazi
# Processing Record 23 of Set 7 | klaksvik
# Processing Record 24 of Set 7 | sapa
# Processing Record 25 of Set 7 | kemijarvi
# Processing Record 26 of Set 7 | isla mujeres
# Processing Record 27 of Set 7 | ishim
# Processing Record 28 of Set 7 | arlit
# Processing Record 29 of Set 7 | roald
# Processing Record 30 of Set 7 | catamarca
# Processing Record 31 of Set 7 | westport
# Processing Record 32 of Set 7 | augusto correa
# Processing Record 33 of Set 7 | okha
# Processing Record 34 of Set 7 | aviles
# Processing Record 35 of Set 7 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 7 | derzhavinsk
# Processing Record 37 of Set 7 | port-de-paix
# City not found. Skipping...
# Processing Record 38 of Set 7 | itoman
# Processing Record 39 of Set 7 | parrita
# Processing Record 40 of Set 7 | henties bay
# Processing Record 41 of Set 7 | eyl
# Processing Record 42 of Set 7 | celestun
# Processing Record 43 of Set 7 | naze
# Processing Record 44 of Set 7 | casablanca
# Processing Record 45 of Set 7 | vaitupu
# City not found. Skipping...
# Processing Record 46 of Set 7 | asosa
# Processing Record 47 of Set 7 | angoche
# Processing Record 48 of Set 7 | maumere
# Processing Record 49 of Set 7 | chippewa falls
# Processing Record 50 of Set 7 | burica
# City not found. Skipping...
# Processing Record 1 of Set 8 | karakendzha
# City not found. Skipping...
# Processing Record 2 of Set 8 | caraballeda
# Processing Record 3 of Set 8 | samana
# Processing Record 4 of Set 8 | lancaster
# Processing Record 5 of Set 8 | rapid valley
# Processing Record 6 of Set 8 | mamallapuram
# Processing Record 7 of Set 8 | sao felix do xingu
# Processing Record 8 of Set 8 | innisfail
# Processing Record 9 of Set 8 | chegdomyn
# Processing Record 10 of Set 8 | demyansk
# Processing Record 11 of Set 8 | umea
# Processing Record 12 of Set 8 | towada
# Processing Record 13 of Set 8 | dunedin
# Processing Record 14 of Set 8 | santa maria
# Processing Record 15 of Set 8 | ust-kuyga
# Processing Record 16 of Set 8 | riyadh
# Processing Record 17 of Set 8 | sampit
# Processing Record 18 of Set 8 | sarandi
# Processing Record 19 of Set 8 | asheville
# Processing Record 20 of Set 8 | tsentralnyy
# City not found. Skipping...
# Processing Record 21 of Set 8 | eltham
# Processing Record 22 of Set 8 | muros
# Processing Record 23 of Set 8 | aykhal
# Processing Record 24 of Set 8 | chiang mai
# Processing Record 25 of Set 8 | ushtobe
# Processing Record 26 of Set 8 | seuzach
# Processing Record 27 of Set 8 | progreso
# Processing Record 28 of Set 8 | balakhta
# Processing Record 29 of Set 8 | curvelo
# Processing Record 30 of Set 8 | vanderhoof
# Processing Record 31 of Set 8 | fortuna
# Processing Record 32 of Set 8 | nadvoitsy
# Processing Record 33 of Set 8 | road town
# Processing Record 34 of Set 8 | ciudad bolivar
# Processing Record 35 of Set 8 | kendari
# Processing Record 36 of Set 8 | ruidoso
# Processing Record 37 of Set 8 | pochutla
# Processing Record 38 of Set 8 | nuuk
# Processing Record 39 of Set 8 | qaqortoq
# Processing Record 40 of Set 8 | bethel
# Processing Record 41 of Set 8 | beboto
# Processing Record 42 of Set 8 | kamenskoye
# City not found. Skipping...
# Processing Record 43 of Set 8 | nguiu
# City not found. Skipping...
# Processing Record 44 of Set 8 | san rafael del sur
# Processing Record 45 of Set 8 | tateyama
# Processing Record 46 of Set 8 | ketchikan
# Processing Record 47 of Set 8 | amapa
# Processing Record 48 of Set 8 | provideniya
# Processing Record 49 of Set 8 | prince rupert
# Processing Record 50 of Set 8 | devonport
# Processing Record 1 of Set 9 | oriximina
# Processing Record 2 of Set 9 | kaka
# Processing Record 3 of Set 9 | ruatoria
# City not found. Skipping...
# Processing Record 4 of Set 9 | barcelos
# Processing Record 5 of Set 9 | kitob
# Processing Record 6 of Set 9 | asau
# Processing Record 7 of Set 9 | bandar-e lengeh
# Processing Record 8 of Set 9 | palmer
# Processing Record 9 of Set 9 | mingguang
# Processing Record 10 of Set 9 | baykit
# Processing Record 11 of Set 9 | saldanha
# Processing Record 12 of Set 9 | indian head
# Processing Record 13 of Set 9 | port elizabeth
# Processing Record 14 of Set 9 | manokwari
# Processing Record 15 of Set 9 | maceio
# Processing Record 16 of Set 9 | nara
# Processing Record 17 of Set 9 | oktyabrskiy
# Processing Record 18 of Set 9 | new milford
# Processing Record 19 of Set 9 | punta gorda
# Processing Record 20 of Set 9 | poum
# Processing Record 21 of Set 9 | nizhnyaya tavda
# Processing Record 22 of Set 9 | caravelas
# Processing Record 23 of Set 9 | desaguadero
# Processing Record 24 of Set 9 | sept-iles
# Processing Record 25 of Set 9 | sao filipe
# Processing Record 26 of Set 9 | bintulu
# Processing Record 27 of Set 9 | sabha
# Processing Record 28 of Set 9 | vestmannaeyjar
# Processing Record 29 of Set 9 | havelock
# Processing Record 30 of Set 9 | margate
# Processing Record 31 of Set 9 | komsomolskiy
# Processing Record 32 of Set 9 | vanimo
# Processing Record 33 of Set 9 | marabba
# Processing Record 34 of Set 9 | encrucijada
# Processing Record 35 of Set 9 | imbituba
# Processing Record 36 of Set 9 | lavrentiya
# Processing Record 37 of Set 9 | labuhan
# Processing Record 38 of Set 9 | newark
# Processing Record 39 of Set 9 | farmington
# Processing Record 40 of Set 9 | pleasant grove
# Processing Record 41 of Set 9 | taltal
# Processing Record 42 of Set 9 | raudeberg
# Processing Record 43 of Set 9 | marawi
# Processing Record 44 of Set 9 | nioro
# Processing Record 45 of Set 9 | kitimat
# Processing Record 46 of Set 9 | batemans bay
# Processing Record 47 of Set 9 | tokur
# Processing Record 48 of Set 9 | talnakh
# Processing Record 49 of Set 9 | astana
# Processing Record 50 of Set 9 | palana
# Processing Record 1 of Set 10 | tambura
# Processing Record 2 of Set 10 | barcelona
# Processing Record 3 of Set 10 | mozarlandia
# Processing Record 4 of Set 10 | coahuayana
# Processing Record 5 of Set 10 | nyanguge
# Processing Record 6 of Set 10 | plettenberg bay
# Processing Record 7 of Set 10 | kysyl-syr
# Processing Record 8 of Set 10 | njombe
# Processing Record 9 of Set 10 | kununurra
# Processing Record 10 of Set 10 | bokspits
# City not found. Skipping...
# Processing Record 11 of Set 10 | kautokeino
# Processing Record 12 of Set 10 | cherskiy
# Processing Record 13 of Set 10 | victoria
# Processing Record 14 of Set 10 | boralday
# Processing Record 15 of Set 10 | raul soares
# Processing Record 16 of Set 10 | touros
# Processing Record 17 of Set 10 | baruun-urt
# Processing Record 18 of Set 10 | camacha
# Processing Record 19 of Set 10 | pangody
# Processing Record 20 of Set 10 | sur
# Processing Record 21 of Set 10 | merauke
# Processing Record 22 of Set 10 | taksimo
# Processing Record 23 of Set 10 | wilmington
# Processing Record 24 of Set 10 | chau doc
# Processing Record 25 of Set 10 | palu
# Processing Record 26 of Set 10 | sumkino
# Processing Record 27 of Set 10 | mehamn
# Processing Record 28 of Set 10 | kirkwall
# Processing Record 29 of Set 10 | dongsheng
# Processing Record 30 of Set 10 | luganville
# Processing Record 31 of Set 10 | bharwari
# Processing Record 32 of Set 10 | coihaique
# Processing Record 33 of Set 10 | uvat
# Processing Record 34 of Set 10 | thoen
# Processing Record 35 of Set 10 | ornskoldsvik
# Processing Record 36 of Set 10 | dalby
# Processing Record 37 of Set 10 | emborion
# Processing Record 38 of Set 10 | wulanhaote
# City not found. Skipping...
# Processing Record 39 of Set 10 | borlange
# City not found. Skipping...
# Processing Record 40 of Set 10 | caldwell
# Processing Record 41 of Set 10 | praya
# Processing Record 42 of Set 10 | ginir
# Processing Record 43 of Set 10 | jumla
# Processing Record 44 of Set 10 | andenes
# Processing Record 45 of Set 10 | chifeng
# Processing Record 46 of Set 10 | rong kwang
# Processing Record 47 of Set 10 | camopi
# Processing Record 48 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 49 of Set 10 | serrana
# Processing Record 50 of Set 10 | louisbourg
# City not found. Skipping...
# Processing Record 1 of Set 11 | svobodnyy
# Processing Record 2 of Set 11 | belyy yar
# Processing Record 3 of Set 11 | leshukonskoye
# Processing Record 4 of Set 11 | vyazma
# Processing Record 5 of Set 11 | escanaba
# Processing Record 6 of Set 11 | arkhangelsk
# Processing Record 7 of Set 11 | chapais
# Processing Record 8 of Set 11 | kahului
# Processing Record 9 of Set 11 | cesis
# Processing Record 10 of Set 11 | jiddah
# City not found. Skipping...
# Processing Record 11 of Set 11 | brigantine
# Processing Record 12 of Set 11 | altay
# Processing Record 13 of Set 11 | antalaha
# Processing Record 14 of Set 11 | amarante do maranhao
# Processing Record 15 of Set 11 | koshurnikovo
# Processing Record 16 of Set 11 | rawson
# Processing Record 17 of Set 11 | pemangkat
# Processing Record 18 of Set 11 | pimentel
# Processing Record 19 of Set 11 | khasan
# Processing Record 20 of Set 11 | sinegorskiy
# Processing Record 21 of Set 11 | laguna
# Processing Record 22 of Set 11 | umm lajj
# Processing Record 23 of Set 11 | urusha
# Processing Record 24 of Set 11 | agadir
# Processing Record 25 of Set 11 | yokote
# Processing Record 26 of Set 11 | goure
# Processing Record 27 of Set 11 | pacific grove
# Processing Record 28 of Set 11 | tromso
# Processing Record 29 of Set 11 | bandarbeyla
# Processing Record 30 of Set 11 | borovskoy
# Processing Record 31 of Set 11 | te anau
# Processing Record 32 of Set 11 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 33 of Set 11 | anda
# Processing Record 34 of Set 11 | yeppoon
# Processing Record 35 of Set 11 | neiafu
# Processing Record 36 of Set 11 | nouakchott
# Processing Record 37 of Set 11 | yinchuan
# Processing Record 38 of Set 11 | bambanglipuro
# Processing Record 39 of Set 11 | kulhudhuffushi
# Processing Record 40 of Set 11 | aktau
# Processing Record 41 of Set 11 | brekstad
# Processing Record 42 of Set 11 | ortona
# Processing Record 43 of Set 11 | tabou
# Processing Record 44 of Set 11 | buchanan
# Processing Record 45 of Set 11 | marzuq
# Processing Record 46 of Set 11 | bayan
# Processing Record 47 of Set 11 | ban pong
# Processing Record 48 of Set 11 | bur gabo
# City not found. Skipping...
# Processing Record 49 of Set 11 | bernay
# Processing Record 50 of Set 11 | christchurch
# Processing Record 1 of Set 12 | laguna de perlas
# Processing Record 2 of Set 12 | victor harbor
# Processing Record 3 of Set 12 | joensuu
# Processing Record 4 of Set 12 | yanan
# City not found. Skipping...
# Processing Record 5 of Set 12 | poplar bluff
# Processing Record 6 of Set 12 | abomsa
# Processing Record 7 of Set 12 | los llanos de aridane
# Processing Record 8 of Set 12 | haaksbergen
# Processing Record 9 of Set 12 | aginskoye
# Processing Record 10 of Set 12 | ritchie
# Processing Record 11 of Set 12 | mokhsogollokh
# Processing Record 12 of Set 12 | saquarema
# Processing Record 13 of Set 12 | pitimbu
# Processing Record 14 of Set 12 | amga
# Processing Record 15 of Set 12 | canarana
# Processing Record 16 of Set 12 | denpasar
# Processing Record 17 of Set 12 | katsuura
# Processing Record 18 of Set 12 | mayo
# Processing Record 19 of Set 12 | sinjar
# Processing Record 20 of Set 12 | southbridge
# Processing Record 21 of Set 12 | urumqi
# Processing Record 22 of Set 12 | malinovskiy
# Processing Record 23 of Set 12 | verkhnyaya khava
# Processing Record 24 of Set 12 | santa cruz del sur
# Processing Record 25 of Set 12 | hays
# Processing Record 26 of Set 12 | mount gambier
# Processing Record 27 of Set 12 | bembibre
# Processing Record 28 of Set 12 | doctor juan leon mallorquin
# Processing Record 29 of Set 12 | yanam
# Processing Record 30 of Set 12 | gollere
# City not found. Skipping...
# Processing Record 31 of Set 12 | hofn
# Processing Record 32 of Set 12 | faya
# Processing Record 33 of Set 12 | jardim
# Processing Record 34 of Set 12 | ocos
# Processing Record 35 of Set 12 | bilma
# Processing Record 36 of Set 12 | varkaus
# Processing Record 37 of Set 12 | thinadhoo
# Processing Record 38 of Set 12 | klyuchevskiy
# Processing Record 39 of Set 12 | sola
# Processing Record 40 of Set 12 | nambucca heads
# Processing Record 41 of Set 12 | lusambo
# Processing Record 42 of Set 12 | bozdar
# Processing Record 43 of Set 12 | atar
# Processing Record 44 of Set 12 | lata
# Processing Record 45 of Set 12 | lompoc
# Processing Record 46 of Set 12 | nemuro
# Processing Record 47 of Set 12 | russell
# Processing Record 48 of Set 12 | noumea
# Processing Record 49 of Set 12 | alim
# Processing Record 50 of Set 12 | la ligua
# Processing Record 1 of Set 13 | tuggurt
# City not found. Skipping...
# Processing Record 2 of Set 13 | catemaco
# Processing Record 3 of Set 13 | guajara-mirim
# City not found. Skipping...
# Processing Record 4 of Set 13 | saint-paul
# Processing Record 5 of Set 13 | yenagoa
# Processing Record 6 of Set 13 | tual
# Processing Record 7 of Set 13 | safaqis
# City not found. Skipping...
# Processing Record 8 of Set 13 | lasa
# Processing Record 9 of Set 13 | orlik
# Processing Record 10 of Set 13 | avera
# Processing Record 11 of Set 13 | yar-sale
# Processing Record 12 of Set 13 | tafo
# Processing Record 13 of Set 13 | whitley bay
# Processing Record 14 of Set 13 | aberdeen
# Processing Record 15 of Set 13 | barroquinha
# Processing Record 16 of Set 13 | xixiang
# Processing Record 17 of Set 13 | pavlovsk
# Processing Record 18 of Set 13 | sinnamary
# Processing Record 19 of Set 13 | karpogory
# Processing Record 20 of Set 13 | conde
# Processing Record 21 of Set 13 | otukpo
# Processing Record 22 of Set 13 | tumbagaan
# Processing Record 23 of Set 13 | gravdal
# Processing Record 24 of Set 13 | tymoshivka
# Processing Record 25 of Set 13 | svetlyy
# Processing Record 26 of Set 13 | usva
# City not found. Skipping...
# Processing Record 27 of Set 13 | shawinigan
# Processing Record 28 of Set 13 | hernani
# Processing Record 29 of Set 13 | zatoka
# Processing Record 30 of Set 13 | tarakan
# Processing Record 31 of Set 13 | surt
# Processing Record 32 of Set 13 | grojec
# Processing Record 33 of Set 13 | mugla
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Get how many cities are in our array of dictionaries
len(city_data)
# Out:
# 589

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0        Barrow  71.29 -156.79    -18.40        68           1       19.46
# 1        Linfen  36.09  111.52     35.56        70          99        3.62
# 2    High Level  58.52 -117.14    -11.20        76          90        2.24
# 3  Punta Arenas -53.15  -70.92     53.60        50          75       23.04
# 4    Bredasdorp -34.53   20.04     71.60        73          94       11.41
# 5      Coquimbo -29.95  -71.34     59.00        77          90        8.05
# 6      Luderitz -26.65   15.16     73.40        69           5       16.11
# 7        Kodiak  57.79 -152.41     42.80        81          75       13.29
# 8      Gonaives  19.45  -72.68     84.88        55           0        3.85
# 9    Oranjemund -28.55   16.43     66.38        83          32       10.49
#
#   Country                 Date
# 0      US  2020-12-22 17:12:47
# 1      CN  2020-12-22 17:12:47
# 2      CA  2020-12-22 17:11:16
# 3      CL  2020-12-22 17:12:48
# 4      ZA  2020-12-22 17:12:48
# 5      CL  2020-12-22 17:12:48
# 6      NA  2020-12-22 17:12:48
# 7      US  2020-12-22 17:12:49
# 8      HT  2020-12-22 17:12:49
# 9      NA  2020-12-22 17:12:49

# %%
# Reorder the columns.
new_column_order = ["City", "Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed"]
city_data_df = city_data_df[new_column_order]
city_data_df.head(10)
# Out:
#            City Country                 Date    Lat     Lng  Max Temp  \
# 0        Barrow      US  2020-12-22 17:12:47  71.29 -156.79    -18.40
# 1        Linfen      CN  2020-12-22 17:12:47  36.09  111.52     35.56
# 2    High Level      CA  2020-12-22 17:11:16  58.52 -117.14    -11.20
# 3  Punta Arenas      CL  2020-12-22 17:12:48 -53.15  -70.92     53.60
# 4    Bredasdorp      ZA  2020-12-22 17:12:48 -34.53   20.04     71.60
# 5      Coquimbo      CL  2020-12-22 17:12:48 -29.95  -71.34     59.00
# 6      Luderitz      NA  2020-12-22 17:12:48 -26.65   15.16     73.40
# 7        Kodiak      US  2020-12-22 17:12:49  57.79 -152.41     42.80
# 8      Gonaives      HT  2020-12-22 17:12:49  19.45  -72.68     84.88
# 9    Oranjemund      NA  2020-12-22 17:12:49 -28.55   16.43     66.38
#
#    Humidity  Cloudiness  Wind Speed
# 0        68           1       19.46
# 1        70          99        3.62
# 2        76          90        2.24
# 3        50          75       23.04
# 4        73          94       11.41
# 5        77          90        8.05
# 6        69           5       16.11
# 7        81          75       13.29
# 8        55           0        3.85
# 9        83          32       10.49

# %%
# Create the output file (CSV).
output_data_file = "weather_data/cities.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")

# %%
# Extract relevant fields from the DataFrame for plotting.
lats = city_data_df["Lat"]
max_temps = city_data_df["Max Temp"]
humidity = city_data_df["Humidity"]
cloudiness = city_data_df["Cloudiness"]
wind_speed = city_data_df["Wind Speed"]

# %%
# Import time module.
import time

# Build the scatter plot for latitude vs. max temperature.
plt.scatter(lats,
           max_temps,
           edgecolor="black",
           linewidths=1,
           marker="o",
           alpha=0.8,
           label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Max Temperature "+ time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig1.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. humidity.
plt.scatter(lats,
           humidity,
           edgecolor="black",
           linewidths=1,
           marker="o",
           alpha=0.8,
           label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Humidity "+ time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig2.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. cloudiness.
plt.scatter(lats,
           cloudiness,
           edgecolor="black",
           linewidths=1,
           marker="o",
           alpha=0.8,
           label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Cloudiness "+ time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig3.png")

# Show plot.
plt.show()

# %%
# Build the scatter plot for latitude vs. wind speed.
plt.scatter(lats,
           wind_speed,
           edgecolor="black",
           linewidths=1,
           marker="o",
           alpha=0.8,
           label="Cities")

# Incorporate the other graph properties.
plt.title(f"City Latitude vs. Wind Speed "+ time.strftime("%x"))
plt.ylabel("Wind Speed (mph))")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure.
plt.savefig("weather_data/Fig4.png")

# Show plot.
plt.show()

# %%
# Import linregress
from scipy.stats import linregress

# Create a function to create perform linear regression on the weather data
# and plot a regression line and the equation with the data.
def plot_linear_regression(x_values, y_values, title, y_label, text_coordinates):

    # Run regression on hemisphere weather data.
    (slope, intercept, r_value, p_value, std_err) = linregress(x_values, y_values)

    # Calculate the regression line "y values" from the slope and intercept.
    regress_values = x_values * slope + intercept
    # Get the equation of the line.
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    # Create a scatter plot and plot the regression line.
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r")
    # Annotate the text for the line equation.
    plt.annotate(line_eq, text_coordinates, fontsize=15, color="red")
    plt.xlabel('Latitude')
    plt.ylabel(y_label)
    plt.title(title)
    plt.show()
    
    print("R-squared: %f" % r_value**2)
    print("P-value: %f" % p_value)

# %%
index13 = city_data_df.loc[13]
index13
# Out:
# City                       Yulara
# Country                        AU
# Date          2020-12-22 17:12:50
# Lat                        -25.24
# Lng                        130.99
# Max Temp                     69.8
# Humidity                       37
# Cloudiness                     82
# Wind Speed                   9.17
# Name: 13, dtype: object

# %%
# Create Northern and Southern Hemisphere DataFrames.
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] < 0)]

# %%
# Linear regression on the Northern Hemisphere (Max Temp)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for Maximum Temperature', 'Max Temp',(5,-40))
# Out:
# R-squared: 0.685859
# P-value: 0.000000

# %%
# Linear regression on the Southern Hemisphere (Max Temp)
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
# Call the function.
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for Maximum Temperature', 'Max Temp',(-53,90))
# Out:
# R-squared: 0.375023
# P-value: 0.000000

# %%
# Linear regression on the Northern Hemisphere (% Humidity)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for % Humidity', '% Humidity',(40,20))
# Out:
# R-squared: 0.184695
# P-value: 0.000000

# %%
# Linear regression on the Southern Hemisphere (% Humidity)
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
# Call the function.
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for % Humidity', 
                       '% Humidity',(-53,20))
# Out:
# R-squared: 0.004467
# P-value: 0.386503

# %%
# Linear regression on the Northern Hemisphere (% Cloudiness)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for % Cloudiness', '% Cloudiness',(40,10))
# Out:
# R-squared: 0.076654
# P-value: 0.000000

# %%
# Linear regression on the Southern Hemisphere (% Cloudiness)
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
# Call the function.
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for % Cloudiness', '% Cloudiness',(-25,10))
# Out:
# R-squared: 0.000969
# P-value: 0.686946

# %%
# Linear regression on the Northern Hemisphere (Wind Speed)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values, 'Linear Regression on the Northern Hemisphere \n for Wind Speed', 'Wind Speed (mph)',(5,40))
# Out:
# R-squared: 0.008321
# P-value: 0.062102

# %%
# Linear regression on the Southern Hemisphere (Wind Speed)
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
# Call the function.
plot_linear_regression(x_values, y_values, 'Linear Regression on the Southern Hemisphere \n for Wind Speed', 'Wind Speed (mph)',(-50,20))
# Out:
# R-squared: 0.023115
# P-value: 0.047795
